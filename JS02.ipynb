# %% [markdown]
# <a href="https://colab.research.google.com/github/PutriAlivia/PCVK_Genap_2021/blob/main/JS02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
cv.rectangle(img_gray,pt1=(0,500), pt2=(100,650),color=(255,255,0),thickness=10)

plt.imshow(img_gray, cmap='GnBu_r')

# %%
plt.imshow(img_gray, cmap='Reds_r')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
plt.imshow(img_gray, cmap='Greens_r')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (17,1024))
plt.imshow(img4)

# %%
img6 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (90,85))
plt.imshow(img6)

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (17,1034))
plt.imshow(img4, cmap='Greens_r')

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
cv.rectangle(img5,pt1=(500,350), pt2=(280,530),color=(255,255,255),thickness=10)
plt.imshow(img5)

# %%
cv.circle(img5, center=(410,420), radius=30,color=(255,0,0),thickness=8)
plt.imshow(img5)

# %%
cv.rectangle(img3,pt1=(0,500), pt2=(100,650),color=(255,255,0),thickness=10)
plt.imshow(img3, cmap='GnBu_r')

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(300,120), pt2=(450,150),color=(255,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(132,432), pt2=(210,150),color=(0,255,255),thickness=5)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(111,222), pt2=(333,444),color=(255,255,255),thickness=6)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(432,321), pt2=(231,123),color=(0,0,255),thickness=4)
plt.imshow(black_img)

# %%
#Membuat Kotak
cv.rectangle(black_img,pt1=(384,0), pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200), pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
#Membuat Lingkaran
cv.circle(black_img, center=(100,100), radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
#Membuat garis
cv.line(black_img, pt1=(0,0), pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hai', org=(10,500),fontFace=font, fontScale=4,color=(255,255,0),thickness=3,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img2)

# %%
vertices = np.array([[100, 300],[200, 200],[400, 300],[200, 400]], dtype=np.int32)
vertices

pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0), thickness=5)
plt.imshow(black_img2)
